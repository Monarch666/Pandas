# %%
import pandas as pd
import numpy as np

# %%
data = {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
'physics': [68, 74, 77, 78],
'chemistry': [84, 56, 73, 69],
'algebra': [78, 88, 82, 87]}

# %%
data
# Out:
# {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
#  'physics': [68, 74, 77, 78],
#  'chemistry': [84, 56, 73, 69],
#  'algebra': [78, 88, 82, 87]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %% [markdown]
# ### To add row in Existing Dataframe

# %%
row={"name":"Ananda","physics":90,"chemistry":85,"algebra":80}

# %%
df=df.append(row,ignore_index=True)
# Out:
# C:\Users\admin\AppData\Local\Temp\ipykernel_8700\484227763.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df=df.append(row,ignore_index=True)

# %%
df
# Out:
#      name  physics  chemistry  algebra
# 0    Somu       68         84       78
# 1    Kiku       74         56       88
# 2    Amol       77         73       82
# 3    Lini       78         69       87
# 4  Ananda       90         85       80

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %% [markdown]
# # APPLY

# %%
def my_mileage(row):
    if row>25:
        return "HIGH"
    else:
        return "LOW"

# %%
data["Mileage_Type"]=data["Mileage"].apply(my_mileage)

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage  test    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 1    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 2   Hyundai  2014       30000      Delhi       27     0     NEW CAR
# 3      Tata  2011       60000     Mumbai       25     0     OLD CAR
# 4  Mahindra  2015       25000      Delhi       26     0     NEW CAR
# 5    Maruti  2012       10000     Mumbai       28     0     NEW CAR
# 6   Hyundai  2016       46000      Delhi       29     0  NORMAL CAR
# 7   Renault  2014       31000     Mumbai       24     0  NORMAL CAR
# 8      Tata  2018       15000    Chennai       21     0     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad       24     0     NEW CAR
#
#   engine type Mileage_Type
# 0       sagar         HIGH
# 1       sagar         HIGH
# 2       sagar         HIGH
# 3       sagar          LOW
# 4       sagar         HIGH
# 5       sagar         HIGH
# 6       sagar         HIGH
# 7       sagar          LOW
# 8       sagar          LOW
# 9       sagar          LOW

# %%
data["test"]=0

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage  test    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 1    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 2   Hyundai  2014       30000      Delhi       27     0     NEW CAR
# 3      Tata  2011       60000     Mumbai       25     0     OLD CAR
# 4  Mahindra  2015       25000      Delhi       26     0     NEW CAR
# 5    Maruti  2012       10000     Mumbai       28     0     NEW CAR
# 6   Hyundai  2016       46000      Delhi       29     0  NORMAL CAR
# 7   Renault  2014       31000     Mumbai       24     0  NORMAL CAR
# 8      Tata  2018       15000    Chennai       21     0     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad       24     0     NEW CAR
#
#   engine type Mileage_Type
# 0       sagar         HIGH
# 1       sagar         HIGH
# 2       sagar         HIGH
# 3       sagar          LOW
# 4       sagar         HIGH
# 5       sagar         HIGH
# 6       sagar         HIGH
# 7       sagar          LOW
# 8       sagar          LOW
# 9       sagar          LOW

# %%
def km(r):
    if r >50000:
        return "OLD CAR"
    elif r>30000 and r<49999:
        return "NORMAL CAR"
    else:
        return "NEW CAR"

# %%
data["CAR_TYPE"]=data["Kms Driven"].apply(km)

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage  test    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 1    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 2   Hyundai  2014       30000      Delhi       27     0     NEW CAR
# 3      Tata  2011       60000     Mumbai       25     0     OLD CAR
# 4  Mahindra  2015       25000      Delhi       26     0     NEW CAR
# 5    Maruti  2012       10000     Mumbai       28     0     NEW CAR
# 6   Hyundai  2016       46000      Delhi       29     0  NORMAL CAR
# 7   Renault  2014       31000     Mumbai       24     0  NORMAL CAR
# 8      Tata  2018       15000    Chennai       21     0     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad       24     0     NEW CAR
#
#   engine type Mileage_Type
# 0       sagar         HIGH
# 1       sagar         HIGH
# 2       sagar         HIGH
# 3       sagar          LOW
# 4       sagar         HIGH
# 5       sagar         HIGH
# 6       sagar         HIGH
# 7       sagar          LOW
# 8       sagar          LOW
# 9       sagar          LOW

# %%
data["engine type"]="sagar"

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage  test    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 1    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 2   Hyundai  2014       30000      Delhi       27     0     NEW CAR
# 3      Tata  2011       60000     Mumbai       25     0     OLD CAR
# 4  Mahindra  2015       25000      Delhi       26     0     NEW CAR
# 5    Maruti  2012       10000     Mumbai       28     0     NEW CAR
# 6   Hyundai  2016       46000      Delhi       29     0  NORMAL CAR
# 7   Renault  2014       31000     Mumbai       24     0  NORMAL CAR
# 8      Tata  2018       15000    Chennai       21     0     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad       24     0     NEW CAR
#
#   engine type Mileage_Type
# 0       sagar         HIGH
# 1       sagar         HIGH
# 2       sagar         HIGH
# 3       sagar          LOW
# 4       sagar         HIGH
# 5       sagar         HIGH
# 6       sagar         HIGH
# 7       sagar          LOW
# 8       sagar          LOW
# 9       sagar          LOW

# %%
#loc[rows,column]

# %%
data.loc[:,["CAR_TYPE","Brand","Year","engine type","Kms Driven","City","Mileage","Mileage_Type"]]

# re-arrange the coln as per your wish
# Out:
#      CAR_TYPE     Brand  Year engine type  Kms Driven       City  Mileage  \
# 0     NEW CAR    Maruti  2012       sagar       50000    Gurgaon       28
# 1     NEW CAR    Maruti  2012       sagar       50000    Gurgaon       28
# 2     NEW CAR   Hyundai  2014       sagar       30000      Delhi       27
# 3     OLD CAR      Tata  2011       sagar       60000     Mumbai       25
# 4     NEW CAR  Mahindra  2015       sagar       25000      Delhi       26
# 5     NEW CAR    Maruti  2012       sagar       10000     Mumbai       28
# 6  NORMAL CAR   Hyundai  2016       sagar       46000      Delhi       29
# 7  NORMAL CAR   Renault  2014       sagar       31000     Mumbai       24
# 8     NEW CAR      Tata  2018       sagar       15000    Chennai       21
# 9     NEW CAR    Maruti  2019       sagar       12000  Ghaziabad       24
#
#   Mileage_Type
# 0         HIGH
# 1         HIGH
# 2         HIGH
# 3          LOW
# 4         HIGH
# 5         HIGH
# 6         HIGH
# 7          LOW
# 8          LOW
# 9          LOW

# %%
data.loc[:,"Brand":"Mileage"]
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.iloc[:,0:5]
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %% [markdown]
# # N-LARGEST and N-Smallest

# %%
data.nlargest(1,"Mileage")

# give top largest or highest or topmost value for the col
# Out:
#      Brand  Year  Kms Driven   City  Mileage Mileage_Type shahji    CAR_TYPE  \
# 6  Hyundai  2016       46000  Delhi       29         HIGH   Hero  NORMAL CAR
#
#   engine type
# 6      petrol

# %%
data.nlargest(3,"Mileage")

# give top 3 largest or 3highest or top3 value for the col
# Out:
#      Brand  Year  Kms Driven     City  Mileage Mileage_Type shahji  \
# 6  Hyundai  2016       46000    Delhi       29         HIGH   Hero
# 0   Maruti  2012       50000  Gurgaon       28         HIGH   Hero
# 1   Maruti  2012       50000  Gurgaon       28         HIGH   Hero
#
#      CAR_TYPE engine type
# 6  NORMAL CAR      petrol
# 0     NEW CAR      petrol
# 1     NEW CAR      petrol

# %%
data.nsmallest(2,"Kms Driven")
# Out:
#     Brand  Year  Kms Driven       City  Mileage Mileage_Type CAR_TYPE  \
# 5  Maruti  2012       10000     Mumbai       28         HIGH  NEW CAR
# 9  Maruti  2019       12000  Ghaziabad       24          LOW  NEW CAR
#
#   engine type
# 5      petrol
# 9      petrol

# %%
data.nsmallest(3,"Kms Driven")
# Out:
#     Brand  Year  Kms Driven       City  Mileage Mileage_Type shahji CAR_TYPE  \
# 5  Maruti  2012       10000     Mumbai       28         HIGH   Hero  NEW CAR
# 9  Maruti  2019       12000  Ghaziabad       24          LOW   Hero  NEW CAR
# 8    Tata  2018       15000    Chennai       21          LOW   Hero  NEW CAR
#
#   engine type
# 5      petrol
# 9      petrol
# 8      petrol

# %%
data.nsmallest(3,"Kms Driven")[["Brand","Year"]]
# Out:
#     Brand  Year
# 5  Maruti  2012
# 9  Maruti  2019
# 8    Tata  2018

# %%
data.nsmallest(3,"Kms Driven")[["Brand"]]
# Out:
#     Brand
# 5  Maruti
# 9  Maruti
# 8    Tata

# %% [markdown]
# # deleting col from the dataframe

# %%
df1=data.drop("Mileage",axis=1)
df1
# Out:
#       Brand  Year  Kms Driven       City  test    CAR_TYPE engine type  \
# 0    Maruti  2012       50000    Gurgaon     0     NEW CAR       sagar
# 1    Maruti  2012       50000    Gurgaon     0     NEW CAR       sagar
# 2   Hyundai  2014       30000      Delhi     0     NEW CAR       sagar
# 3      Tata  2011       60000     Mumbai     0     OLD CAR       sagar
# 4  Mahindra  2015       25000      Delhi     0     NEW CAR       sagar
# 5    Maruti  2012       10000     Mumbai     0     NEW CAR       sagar
# 6   Hyundai  2016       46000      Delhi     0  NORMAL CAR       sagar
# 7   Renault  2014       31000     Mumbai     0  NORMAL CAR       sagar
# 8      Tata  2018       15000    Chennai     0     NEW CAR       sagar
# 9    Maruti  2019       12000  Ghaziabad     0     NEW CAR       sagar
#
#   Mileage_Type
# 0         HIGH
# 1         HIGH
# 2         HIGH
# 3          LOW
# 4         HIGH
# 5         HIGH
# 6         HIGH
# 7          LOW
# 8          LOW
# 9          LOW

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage  test    CAR_TYPE  \
# 0    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 1    Maruti  2012       50000    Gurgaon       28     0     NEW CAR
# 2   Hyundai  2014       30000      Delhi       27     0     NEW CAR
# 3      Tata  2011       60000     Mumbai       25     0     OLD CAR
# 4  Mahindra  2015       25000      Delhi       26     0     NEW CAR
# 5    Maruti  2012       10000     Mumbai       28     0     NEW CAR
# 6   Hyundai  2016       46000      Delhi       29     0  NORMAL CAR
# 7   Renault  2014       31000     Mumbai       24     0  NORMAL CAR
# 8      Tata  2018       15000    Chennai       21     0     NEW CAR
# 9    Maruti  2019       12000  Ghaziabad       24     0     NEW CAR
#
#   engine type Mileage_Type
# 0       sagar         HIGH
# 1       sagar         HIGH
# 2       sagar         HIGH
# 3       sagar          LOW
# 4       sagar         HIGH
# 5       sagar         HIGH
# 6       sagar         HIGH
# 7       sagar          LOW
# 8       sagar          LOW
# 9       sagar          LOW

# %%
data.drop("Mileage",axis=1,inplace=True)

# %%
# inplace : make changes in orginal df

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  test    CAR_TYPE engine type  \
# 0    Maruti  2012       50000    Gurgaon     0     NEW CAR       sagar
# 1    Maruti  2012       50000    Gurgaon     0     NEW CAR       sagar
# 2   Hyundai  2014       30000      Delhi     0     NEW CAR       sagar
# 3      Tata  2011       60000     Mumbai     0     OLD CAR       sagar
# 4  Mahindra  2015       25000      Delhi     0     NEW CAR       sagar
# 5    Maruti  2012       10000     Mumbai     0     NEW CAR       sagar
# 6   Hyundai  2016       46000      Delhi     0  NORMAL CAR       sagar
# 7   Renault  2014       31000     Mumbai     0  NORMAL CAR       sagar
# 8      Tata  2018       15000    Chennai     0     NEW CAR       sagar
# 9    Maruti  2019       12000  Ghaziabad     0     NEW CAR       sagar
#
#   Mileage_Type
# 0         HIGH
# 1         HIGH
# 2         HIGH
# 3          LOW
# 4         HIGH
# 5         HIGH
# 6         HIGH
# 7          LOW
# 8          LOW
# 9          LOW

# %% [markdown]
# axis=1 column -one
#
# axis=0 row -zero

# %%
data.drop("Year",axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 data.drop("Year",axis=0)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Year'] not found in axis"

# %%
data.drop("Year",axis=1)
# Out:
#       Brand  Kms Driven       City  test    CAR_TYPE engine type Mileage_Type
# 0    Maruti       50000    Gurgaon     0     NEW CAR       sagar         HIGH
# 1    Maruti       50000    Gurgaon     0     NEW CAR       sagar         HIGH
# 2   Hyundai       30000      Delhi     0     NEW CAR       sagar         HIGH
# 3      Tata       60000     Mumbai     0     OLD CAR       sagar          LOW
# 4  Mahindra       25000      Delhi     0     NEW CAR       sagar         HIGH
# 5    Maruti       10000     Mumbai     0     NEW CAR       sagar         HIGH
# 6   Hyundai       46000      Delhi     0  NORMAL CAR       sagar         HIGH
# 7   Renault       31000     Mumbai     0  NORMAL CAR       sagar          LOW
# 8      Tata       15000    Chennai     0     NEW CAR       sagar          LOW
# 9    Maruti       12000  Ghaziabad     0     NEW CAR       sagar          LOW

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})

# %%
data.drop(["Year","City"],axis=1)
# Out:
#       Brand  Kms Driven  Mileage
# 0    Maruti       50000       28
# 1    Maruti       50000       28
# 2   Hyundai       30000       27
# 3      Tata       60000       25
# 4  Mahindra       25000       26
# 5    Maruti       10000       28
# 6   Hyundai       46000       29
# 7   Renault       31000       24
# 8      Tata       15000       21
# 9    Maruti       12000       24

# %%
del data["Year"]

# %%
data
# Out:
#       Brand  Kms Driven       City  Mileage
# 0    Maruti       50000    Gurgaon       28
# 1    Maruti       50000    Gurgaon       28
# 2   Hyundai       30000      Delhi       27
# 3      Tata       60000     Mumbai       25
# 4  Mahindra       25000      Delhi       26
# 5    Maruti       10000     Mumbai       28
# 6   Hyundai       46000      Delhi       29
# 7   Renault       31000     Mumbai       24
# 8      Tata       15000    Chennai       21
# 9    Maruti       12000  Ghaziabad       24

# %%
# drop
# del
# pop

# %%
data.pop("Mileage")
# Out:
# 0    28
# 1    28
# 2    27
# 3    25
# 4    26
# 5    28
# 6    29
# 7    24
# 8    21
# 9    24
# Name: Mileage, dtype: int64

# %%
data
# Out:
#       Brand  Kms Driven       City
# 0    Maruti       50000    Gurgaon
# 1    Maruti       50000    Gurgaon
# 2   Hyundai       30000      Delhi
# 3      Tata       60000     Mumbai
# 4  Mahindra       25000      Delhi
# 5    Maruti       10000     Mumbai
# 6   Hyundai       46000      Delhi
# 7   Renault       31000     Mumbai
# 8      Tata       15000    Chennai
# 9    Maruti       12000  Ghaziabad

# %% [markdown]
# ### deleting rows

# %%
data = pd.DataFrame({'Brand' : ['Maruti','Maruti', 'Hyundai', 'Tata',
                                'Mahindra', 'Maruti', 'Hyundai',
                                'Renault', 'Tata', 'Maruti'],
                     'Year' : [2012,2012, 2014, 2011, 2015, 2012, 
                               2016, 2014, 2018, 2019],
                     'Kms Driven' : [50000,50000, 30000, 60000, 
                                     25000, 10000, 46000, 
                                     31000, 15000, 12000],
                     'City' : ['Gurgaon','Gurgaon', 'Delhi', 'Mumbai', 
                               'Delhi', 'Mumbai', 'Delhi', 
                               'Mumbai','Chennai',  'Ghaziabad'],
                     'Mileage' :  [28,28, 27, 25, 26, 28, 
                                   29, 24, 21, 24]})

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.drop([0,4,5,9])
# Out:
#      Brand  Year  Kms Driven     City  Mileage
# 1   Maruti  2012       50000  Gurgaon       28
# 2  Hyundai  2014       30000    Delhi       27
# 3     Tata  2011       60000   Mumbai       25
# 6  Hyundai  2016       46000    Delhi       29
# 7  Renault  2014       31000   Mumbai       24
# 8     Tata  2018       15000  Chennai       21

# %%
data.drop(range(4,8))   #range(start,stop,step)   /   l[start:stop:step]
# Out:
#      Brand  Year  Kms Driven       City  Mileage
# 0   Maruti  2012       50000    Gurgaon       28
# 1   Maruti  2012       50000    Gurgaon       28
# 2  Hyundai  2014       30000      Delhi       27
# 3     Tata  2011       60000     Mumbai       25
# 8     Tata  2018       15000    Chennai       21
# 9   Maruti  2019       12000  Ghaziabad       24

# %%
data.drop(data.index[0:4])

# this is position based
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
df = {'name': ['Somu', 'Kiku', 'Amol', 'Lini'],
'physics': [68, 74, 77, 78],
'chemistry': [84, 56, 73, 69],
'algebra': [78, 88, 82, 87]}

df_1=pd.DataFrame(df)

# %%
df_1
# Out:
#    name  physics  chemistry  algebra
# 0  Somu       68         84       78
# 1  Kiku       74         56       88
# 2  Amol       77         73       82
# 3  Lini       78         69       87

# %%
df_1.set_index("name",inplace=True)

#  how to make a col index

# %%
df_1
# Out:
#       physics  chemistry  algebra
# name
# Somu       68         84       78
# Kiku       74         56       88
# Amol       77         73       82
# Lini       78         69       87

# %%
df_1.drop(["Somu","Kiku"])
# Out:
#       physics  chemistry  algebra
# name
# Amol       77         73       82
# Lini       78         69       87

# %%
df_1.drop(df_1.index[0:2])
# Out:
#       physics  chemistry  algebra
# name
# Amol       77         73       82
# Lini       78         69       87

# %% [markdown]
# ## Renaming the col_names

# %%
data
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 0    Maruti  2012       50000    Gurgaon       28
# 1    Maruti  2012       50000    Gurgaon       28
# 2   Hyundai  2014       30000      Delhi       27
# 3      Tata  2011       60000     Mumbai       25
# 4  Mahindra  2015       25000      Delhi       26
# 5    Maruti  2012       10000     Mumbai       28
# 6   Hyundai  2016       46000      Delhi       29
# 7   Renault  2014       31000     Mumbai       24
# 8      Tata  2018       15000    Chennai       21
# 9    Maruti  2019       12000  Ghaziabad       24

# %%
data.rename(columns={"Brand":"A","Mileage":"M"})
# Out:
#           A  Year  Kms Driven       City   M
# 0    Maruti  2012       50000    Gurgaon  28
# 1    Maruti  2012       50000    Gurgaon  28
# 2   Hyundai  2014       30000      Delhi  27
# 3      Tata  2011       60000     Mumbai  25
# 4  Mahindra  2015       25000      Delhi  26
# 5    Maruti  2012       10000     Mumbai  28
# 6   Hyundai  2016       46000      Delhi  29
# 7   Renault  2014       31000     Mumbai  24
# 8      Tata  2018       15000    Chennai  21
# 9    Maruti  2019       12000  Ghaziabad  24

# %%
index=list(range(9,-1,-1))
index
# Out:
# [9, 8, 7, 6, 5, 4, 3, 2, 1, 0]

# %%
index=list(range(9,-1,-1))
data.reindex(index)

# to change the row index
# Out:
#       Brand  Year  Kms Driven       City  Mileage
# 9    Maruti  2019       12000  Ghaziabad       24
# 8      Tata  2018       15000    Chennai       21
# 7   Renault  2014       31000     Mumbai       24
# 6   Hyundai  2016       46000      Delhi       29
# 5    Maruti  2012       10000     Mumbai       28
# 4  Mahindra  2015       25000      Delhi       26
# 3      Tata  2011       60000     Mumbai       25
# 2   Hyundai  2014       30000      Delhi       27
# 1    Maruti  2012       50000    Gurgaon       28
# 0    Maruti  2012       50000    Gurgaon       28

# %% [markdown]
# # Handling missing data

# %%
df_weather=pd.read_excel(r"C:\Users\admin\Downloads\IMP python modules\whether_data.xls")

# %%
df_weather
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
df_weather.drop("windspeed",axis=1,inplace=True)

# %%
df_weather
# Out:
#          day  temperature   event
# 0 2017-01-01         32.0    Rain
# 1 2017-01-04          NaN   Sunny
# 2 2017-01-05         28.0    Snow
# 3 2017-01-06          NaN     NaN
# 4 2017-01-07         32.0    Rain
# 5 2017-01-08         31.0   Sunny
# 6 2017-01-09          NaN     NaN
# 7 2017-01-10         34.0  Cloudy
# 8 2017-01-11         40.0     NaN

# %%
df_weather.to_csv(r"C:\Users\admin\Downloads\IMP python modules\whether.txt",sep=",")

# %%
df_weather.to_excel(r"C:\Users\admin\Downloads\IMP python modules\IPCS.xlsx")

# %%
df_weather.to_excel
# Out:
# <bound method NDFrame.to_excel of          day      city  temperature   event
# 0   1/1/2017  new york           32    Rain
# 1   1/2/2017  new york           36   Sunny
# 2   1/3/2017  new york           28    Snow
# 3   1/4/2017  new york           33   Sunny
# 4   1/1/2017    mumbai           90   Sunny
# 5   1/2/2017    mumbai           85     Fog
# 6   1/3/2017    mumbai           87     Fog
# 7   1/4/2017    mumbai           92    Rain
# 8   1/1/2017     paris           45   Sunny
# 9   1/2/2017     paris           50  Cloudy
# 10  1/3/2017     paris           54  Cloudy
# 11  1/4/2017     paris           42  Cloudy>

# %%
df_weather
# Out:
#          day  temperature   event
# 0   1/1/2017         32.0    Rain
# 1   1/4/2017          NaN   Sunny
# 2   1/5/2017         28.0    Snow
# 3   1/6/2017          NaN     NaN
# 4   1/7/2017         32.0    Rain
# 5   1/8/2017          NaN   Sunny
# 6   1/9/2017          NaN     NaN
# 7  1/10/2017         34.0  Cloudy
# 8  1/11/2017         40.0   Sunny

# %%
df_weather.dtypes
# Out:
# day             object
# temperature    float64
# event           object
# dtype: object

# %%
df_weather=pd.read_excel(r"C:\Users\admin\Downloads\IMP python modules\whether_data.xls",parse_dates=["day"])

# %%
df_weather
# Out:
#          day  temperature  windspeed   event
# 0 2017-01-01         32.0        6.0    Rain
# 1 2017-01-04          NaN        7.0   Sunny
# 2 2017-01-05         28.0        NaN    Snow
# 3 2017-01-06          NaN        7.0     NaN
# 4 2017-01-07         32.0        NaN    Rain
# 5 2017-01-08         31.0        2.0   Sunny
# 6 2017-01-09          NaN        NaN     NaN
# 7 2017-01-10         34.0        8.0  Cloudy
# 8 2017-01-11         40.0       12.0     NaN

# %%
df_weather.dtypes
# Out:
# day            datetime64[ns]
# temperature           float64
# windspeed             float64
# event                  object
# dtype: object

# %%
df_weather.set_index("event",inplace=True)
df_weather
# Out:
#               day  temperature  windspeed
# event
# Rain   2017-01-01         32.0        6.0
# Sunny  2017-01-04          NaN        7.0
# Snow   2017-01-05         28.0        NaN
# NaN    2017-01-06          NaN        7.0
# Rain   2017-01-07         32.0        NaN
# Sunny  2017-01-08         31.0        2.0
# NaN    2017-01-09          NaN        NaN
# Cloudy 2017-01-10         34.0        8.0
# NaN    2017-01-11         40.0       12.0

# %%
df_weather.isnull().sum()
# Out:
# temperature    4
# windspeed      4
# event          2
# dtype: int64

# %%
df_weather
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %% [markdown]
# ### To remove rows with nan values

# %%
df_weather
# Out:
#               day  temperature  windspeed
# event
# Rain   2017-01-01         32.0        6.0
# Sunny  2017-01-04          NaN        7.0
# Snow   2017-01-05         28.0        NaN
# NaN    2017-01-06          NaN        7.0
# Rain   2017-01-07         32.0        NaN
# Sunny  2017-01-08         31.0        2.0
# NaN    2017-01-09          NaN        NaN
# Cloudy 2017-01-10         34.0        8.0
# NaN    2017-01-11         40.0       12.0

# %%
df_weather.dropna()
# Out:
#               day  temperature  windspeed
# event
# Rain   2017-01-01         32.0        6.0
# Sunny  2017-01-08         31.0        2.0
# Cloudy 2017-01-10         34.0        8.0
# NaN    2017-01-11         40.0       12.0

# %%
df_weather.dropna(how="all")
# all, when all rows value are Nan then remove that row
# Out:
#               day  temperature  windspeed
# event
# Rain   2017-01-01         32.0        6.0
# Sunny  2017-01-04          NaN        7.0
# Snow   2017-01-05         28.0        NaN
# NaN    2017-01-06          NaN        7.0
# Rain   2017-01-07         32.0        NaN
# Sunny  2017-01-08         31.0        2.0
# NaN    2017-01-09          NaN        NaN
# Cloudy 2017-01-10         34.0        8.0
# NaN    2017-01-11         40.0       12.0

# %%
df_weather.dropna(how="any")
# , when any rows has any  Nan then remove that row
# Out:
#               day  temperature  windspeed
# event
# Rain   2017-01-01         32.0        6.0
# Sunny  2017-01-08         31.0        2.0
# Cloudy 2017-01-10         34.0        8.0
# NaN    2017-01-11         40.0       12.0

# %%
df_weather
# Out:
#             temperature  windspeed   event
# day
# 2017-01-01         32.0        6.0    Rain
# 2017-01-04          NaN        9.0   Sunny
# 2017-01-05         28.0        NaN    Snow
# 2017-01-06          NaN        7.0     NaN
# 2017-01-07         32.0        NaN    Rain
# 2017-01-08          NaN        NaN   Sunny
# 2017-01-09          NaN        NaN     NaN
# 2017-01-10         34.0        8.0  Cloudy
# 2017-01-11         40.0       12.0   Sunny

# %%
df_weather["windspeed"].mean()
# Out:
# 8.4
